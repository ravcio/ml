# %%
import pandas as pd
import numpy as np

df=pd.DataFrame([2,3,4])
df
# Out:
#    0
# 0  2
# 1  3
# 2  4

# %% [markdown]
# # Tytuł
#
# Formuła: $a=4^5$.

# %%
mat = np.random.random((30,30))
df = pd.DataFrame(mat)
df.T
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.811157  0.180727  0.913979  0.845390  0.721154  0.314096  0.536087
# 1   0.167038  0.291473  0.718252  0.279315  0.080722  0.248986  0.473177
# 2   0.065943  0.403115  0.574214  0.194626  0.215585  0.683750  0.834368
# 3   0.506195  0.411799  0.176797  0.921704  0.878392  0.559938  0.084860
# 4   0.995911  0.780506  0.585273  0.645665  0.502249  0.668875  0.467514
# 5   0.165718  0.999573  0.544579  0.425074  0.176192  0.834500  0.324399
# 6   0.898592  0.570397  0.864351  0.224493  0.123429  0.710671  0.345204
# 7   0.584033  0.679500  0.063068  0.190459  0.381976  0.295257  0.969980
# 8   0.090555  0.642418  0.080634  0.480020  0.435609  0.767574  0.826642
# 9   0.473536  0.015693  0.671231  0.717181  0.215739  0.763185  0.368567
# 10  0.802421  0.078102  0.338695  0.224792  0.266178  0.424975  0.363667
# 11  0.480563  0.982586  0.174361  0.036944  0.219013  0.990322  0.665620
# ...

# %%
df = pd.DataFrame(np.random.randn(1000))
df[0].plot()
None
